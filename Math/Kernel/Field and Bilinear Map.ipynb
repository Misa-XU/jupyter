# %% [markdown]
# ## Field
# A field is a set $\mathbb F$ together with two operations on $\mathbb F$ called addition and multiplication.
#
# An operation on $\mathbb F$ is a function $\mathbb{F \times F \to F}$ – in other words, a mapping that associates an element of $\mathbb F$ to every pair of its elements. The result of the addition of $a$ and $b$ is called the sum of $a$ and $b$, and is denoted $a + b$. Similarly, the result of the multiplication of $a$ and $b$ is called the product of $a$ and $b$, and is denoted ab or $a \cdot b$.
#
# These operations are required to satisfy the following properties, referred to as field axioms. In these axioms, $a$, $b$, and $c$ are arbitrary elements of the field $\mathbb F$.
#
# 1. __Associativity__ of addition and multiplication: a + (b + c) = (a + b) + c, and a · (b · c) = (a · b) · c.
# 2. __Commutativity__ of addition and multiplication: a + b = b + a, and a · b = b · a.
# 3. __Identity__ of additive and multiplicative: there exist two different elements 0 and 1 in $\mathbb F$ such that a + 0 = a and a · 1 = a.
# 4. __Additive inverses__: for every $a \in \mathbb F$, there exists an element in $\mathbb F$, denoted $−a$, called the additive inverse of a, such that $a + (−a) = 0$.
# 5. __Multiplicative inverses__: for every $a \ne 0 \in F$, there exists an element in $\mathbb F$, denoted by $a^{−1}$ or $\frac{1}{a}$, called the multiplicative inverse of $a$, such that $a \cdot a^{−1} = 1$.
# 6. __Distributivity__ of multiplication over addition: $a \cdot (b + c) = (a \cdot b) + (a \cdot c)$.

# %% [markdown]
# ## Bilinear map
# Let $V$ , $W$  and  $X$ be three vector spaces over the same base field $\mathbb {F}$. A bilinear map is a function
# $$B:V\times W\to X$$ such that
# $\forall w\in W$, the map $$B_{w} : v \mapsto B(v,w)$$ is a linear map from $V$ to $X$.
#
# And $\forall v\in V$, the map $$B_{v} : w \mapsto B(v,w)$$ is a linear map from $W$ to $X$.
#
# In other words, when we hold the first entry of the bilinear map fixed while letting the second entry vary, the result is a linear operator, and similarly for when we hold the second entry fixed.  If $V = W$ and we have $B(v, w) = B(w, v) \, \forall v, w \in V$, then we say that $B$ is symmetric. The case where $X$ is the base field $\mathbb F$, and we have a bilinear form, is particularly useful.
#
# The vector space of linear maps $V \to V$ is isomorphic to the bilinear functionals $V \times V \to R$.

# %% [markdown]
# ## Vector Space
# A vector space over a field $\mathbb F$ is a set $\mathbb V$ together with __two operations__ that satisfy the __eight axioms__ listed below.
#
# 1. __Addition__ + : $V \times V \to V$, takes any two vectors $v$ and $w$ and assigns to them a third vector which is commonly written as $v + w$, and called the sum of these two vectors.
# 2. __Scalar multiplication__ · : $F \times V \to V$， takes any scalar $a$ and any vector $v$ and gives another vector $av$.
#
# To qualify as a vector space, the set $V$ and the operations of addition and multiplication must adhere to a number of requirements called axioms. In the list below, let $u$, $v$ and $w$ be arbitrary vectors in $V$, and $a$ and $b$ scalars in $\mathbb F$.
#
# Axiom	| Meaning
# :--- | :---
# Associativity of addition	| $ u + (v + w) = (u + v) + w$
# Commutativity of addition	| $u + v = v + u$
# Identity element of addition	| There exists an element $0 \in V$, called the zero vector, such that $v + 0 = v$ for all $v \in V$.
# Inverse elements of addition	| For every $v \in V$, there exists an element $−v \in V$, called the additive inverse of $v$, such that $v + (−v) = 0$.
# Compatibility of scalar multiplication with field multiplication	| $a(bv) = (ab)v$
# Identity element of scalar multiplication	| $1v = v$, where 1 denotes the multiplicative identity in $\mathbb F$.
# Distributivity of scalar multiplication with respect to vector addition| $a(u + v) = au + av$
# Distributivity of scalar multiplication with respect to field addition| $(a + b)v = av + bv$
#
# ### Norm
# Given a vector space $V$ over a subfield $\mathbb F$ of the complex numbers, a __norm__ on $V$ is a nonnegative-valued scalar function p: $V \to [0,+\infty)$ with the following properties for all $a \in \mathbb F$ and all $u,\, v \in V$:
# 1. $p(u + v) \le p(u) + p(v)$ (being subadditive or satisfying the triangle inequality).
# 2. $p(av) = |a| p(v)$ (being absolutely homogeneous or absolutely scalable).
# 3. If p(v) = 0 then v = 0 is the zero vector (being positive definite or being point-separating).
# If only 1 and 2 holds, but assign zero length to some non-zero vectors, it's called a __seminorm__
#
# ### Normed Space
# 1. A __normed vector space__ is a pair $ (V,\|\cdot \|)$ where $V$ is a vector space and $\|\cdot \|$ is a norm on $V$.
# 2. A __seminormed vector space__ is a pair $(V,p)$ where $V$ is a vector space and $p$ a seminorm on $V$.

# %% [markdown]
# ## $L^p$ Space
# #### $L^p$ Norms
# For a real number $p \ge 1$, the $L^p$-norm of x is defined by
# $$\left\|x\right\|_{p}=\left(|x_{1}|^{p}+|x_{2}|^{p}+\dotsb +|x_{n}|^{p}\right)^{1/p}$$
#
# For all $p \ge 1$, the p-norms and maximum norm as defined above indeed satisfy the properties of a "length function" (or norm), with the following properties:
# 1. $||x||_{p + a} ≤ ||x||_p$ for any vector x and real numbers p ≥ 1 and a ≥ 0.
# 2. for vectors in $C^n$ where $0 < r < p$:
# $\left\|x\right\|_{p}\leq \left\|x\right\|_{r}\leq n^{(1/r-1/p)}\left\|x\right\|_{p}$
#
# #### The p-norm in countably infinite dimensions and $ℓ^p$ spaces
# The p-norm can be extended to vectors that have an infinite number of components, which yields the space ℓ p. This contains as special cases:
# - ℓ 1, the space of sequences whose series is absolutely convergent,
# - ℓ 2, the space of square-summable sequences, which is a Hilbert space, and
# - ℓ ∞, the space of bounded sequences.
#
# #### Subaddictive
# A subadditive function is a function $f\colon A\to B$ having a domain A and an ordered codomain B that are both closed under addition, with the following property:
# $$\forall x,y\in A,f(x+y)\leq f(x)+f(y)$$
#
# A sequence $\left\{a_{n}\right\},n\geq 1$ is called subadditive if it satisfies the inequality$$\qquad a_{n+m}\leq a_{n}+a_{m}$$
#
# #### Homogeneous Function
# More generally, if ƒ : V → W is a function between two vector spaces over a field F, and k is an integer, then ƒ is said to be homogeneous of degree k if for all nonzero $α \in F$ and $v \in V$
# $$f(\alpha \mathbf {v} )=\alpha ^{k}f(\mathbf {v})$$

# %% [markdown]
# ## Inner Product Space
# In linear algebra, an inner product space is a vector space with an additional structure called an inner product. An inner product naturally induces an associated norm, thus an inner product space is also a normed vector space. A complete space with an inner product is a __Hilbert space__.
#
# The field of scalars denoted $\mathbb F$ below is either the field of real numbers $\mathbb R$ or the field of complex numbers $\mathbb C$.
#
# Formally, an inner product space is a vector space $V$ over the field $\mathbb F$ together with an inner product, i.e., a map
#
# $$\langle \cdot ,\cdot \rangle :V\times V\to F$$
# That satisfies the following three properties for all vectors $x,\, y,\, z \in V$ and all scalars $a \in \mathbb F$
#
# 1. Conjugate symmetry:
# $\langle x,y\rangle ={\overline {\langle y,x\rangle }}$
# 2. Linearity in the first argument:
# $$\begin{aligned}\langle ax,y\rangle &=a\langle x,y\rangle \\\langle x+y,z\rangle &=\langle x,z\rangle +\langle y,z\rangle \end{aligned}$$
# 3. Positive-definite:
# $$\langle x,x\rangle >0,\quad x\in V\setminus \{\mathbf {0} \}$$
#
# Note that Conjugate symmetry and linearity in the first variable imply
#
# $$\begin{aligned}\langle x,ay\rangle &={\overline {\langle ay,x\rangle }}={\overline {a}}{\overline {\langle y,x\rangle }}={\overline {a}}\langle x,y\rangle \\\langle x,y+z\rangle &={\overline {\langle y+z,x\rangle }}={\overline {\langle y,x\rangle }}+{\overline {\langle z,x\rangle }}=\langle x,y\rangle +\langle x,z\rangle \,;\end{aligned}$$
#
# That is, conjugate linearity in the second argument. So, an inner product is a sesquilinear form. Conjugate symmetry is also called Hermitian symmetry, and a conjugate-symmetric sesquilinear form is called a Hermitian form. While the above axioms are more mathematically economical, a compact verbal definition of __an inner product is a positive-definite Hermitian form__.
#
# #### Properties
# 1. __Cauchy–Schwarz inequality__<br>
# For $x, y$ elements of $V$
# $$|\langle x,y\rangle |\leq \|x\|\,\|y\|$$ with equality if and only if $x$ and $y$ are linearly dependent.
#
# 2. __Orthogonality__<br>
# The angle between two non-zero vectors x and y (denoted ∠) in the case $\mathbb F = \mathbb R$ by the identity
# $$\angle (x,y)=\arccos {\frac {\langle x,y\rangle }{\|x\|\,\|y\|}}$$
# We assume the value of the angle is chosen to be in the interval $[0, \pi]$ which is in analogy to the situation in two-dimensional Euclidean space. <br>
# In the case $\mathbb F = \mathbb C$, the angle in the interval $[0,\frac{\pi}{2}]$ is typically defined by
# $$\angle (x,y)=\arccos {\frac {|\langle x,y\rangle |}{\|x\|\,\|y\|}}$$
# Correspondingly, we will say that non-zero vectors x and y of V are orthogonal if and only if their inner product is zero.
# 3. __Homogeneity__<br>
# For $x$ an element of $V$ and $r$ a scalar:
# $\|rx\|=\|r\|\,\|x\|$
# 4. __Triangle inequality__ <br>
# For $x$, $y$ elements of $V$: $\|x+y\|\leq \|x\|+\|y\|$
# 5. __Pythagorean theorem__ <br>
# Whenever $x, y$ are in $V$ and $\langle x, y\rangle = 0$, then $\|x\|^{2}+\|y\|^{2}=\|x+y\|^{2}$
# 6. __Parseval's identity__<br>
# $\sum _{i=1}^{\infty }\|x_{i}\|^{2}=\left\|\sum _{i=1}^{\infty }x_{i}\right\|^{2}$
# 7. __Parallelogram law__ <br>
# For $x, y$ elements of $V$,
# $\|x+y\|^{2}+\|x-y\|^{2}=2\|x\|^{2}+2\|y\|^{2}$
# The parallelogram law is, in fact, a necessary and sufficient condition for the existence of a inner product corresponding to a given norm. If it holds, the inner product is defined by the polarization identity:
# $\|x+y\|^{2}=\|x\|^{2}+\|y\|^{2}+2\operatorname {Re} \langle x,y\rangle$ which is a form of the law of cosines.
# 8. __Ptolemy's inequality__ <br>
# For $x, y, z$ elements of $V$,
# $\|x-y\|\|z\|+\|y-z\|\|x\|\geq \|x-z\|\|y\|$
#
# Note that a linear space with a norm such as $$\|x\|_{p}=\left(\sum _{i=1}^{\infty }\left|\xi _{i}\right|^{p}\right)^{\frac {1}{p}}\qquad x=\left\{\xi _{i}\right\}\in l^{p},\quad p\neq 2$$ is a normed space but not an inner product space, because this norm does not satisfy the parallelogram equality required of a norm to have an inner product associated with it.
#
# So the Inner Product defined on ℓ_2 for all sequences $(xn),(yn) ∈ ℓ2$ is$$⟨(x_n),(y_n)⟩=\sum_{n=1}^{∞}x_n y_n$$
# Similarly, an Inner Product on $L^2(E)$ for all $f,g∈L2(E)$ is $$⟨f,g⟩=∫Ef(x)g(x)dx$$

# %% [markdown]
# ## Tensor
# #### Dual Space
# Given any vector space $V$ over a field $\mathbb F$, the (algebraic) dual space $V^∗$ (alternatively denoted by $V^{\vee }$ or $V'$ is defined as the set of all linear maps $$φ: V → F$$
# Since linear maps are vector space homomorphisms, the dual space is also sometimes denoted by Hom(V, F). The dual space $V^∗$ itself becomes a vector space over $\mathbb F$ when equipped with an addition and scalar multiplication satisfying:
# $$\begin{aligned}(\varphi +\psi )(x)&=\varphi (x)+\psi (x)\\(a\varphi )(x)&=a\left(\varphi (x)\right)\end{aligned}$$
# for all $φ$ and $ψ ∈ V∗$, $x ∈ V$, and $a ∈ F$
#
# The pairing of a functional $φ$ in the dual space $V^∗$ and an element $x$ of $V$ is sometimes denoted by a bracket: $φ(x) = [x,φ]$ or $φ(x) = ⟨φ,x⟩$. This pairing defines a nondegenerate bilinear mapping $⟨·,·⟩ : V^∗ × V → F$ which called the natural pairing.
#
# In mathematics, a tensor is an algebraic object related to a vector space and its dual space that can be defined in several different ways, often a scalar, tangent vector at a point, a cotangent vector (dual vector) at a point or a multi-linear map from vector spaces to a resulting vector space.
